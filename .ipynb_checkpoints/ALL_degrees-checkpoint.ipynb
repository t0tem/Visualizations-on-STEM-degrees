# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### All degrees plotted in 3 groups

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')

# %%
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science', 
             'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 
                 'Communications and Journalism', 'Art and Performance', 
                 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 
              'Education', 'Agriculture','Business', 'Architecture']

# %%
# Reusable functions

def plot_ax(lst, ax, i):
    ax.plot(women_degrees['Year'], women_degrees[lst[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lst[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lst[i])
    return None

def tune_ax(lst, ax): # 'lst' holds categories names 
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)    
    
    ax.tick_params(bottom="off", top="off", 
                   left="off", right="off")
    return None

def add_labes(lst, ax, i):
        men_ycoord = 100-women_degrees.loc[41, lst[i]]
        women_ycoord = women_degrees.loc[41, lst[i]]
        ax.text(2005, 
                (men_ycoord >= 50.0)*(men_ycoord+7) + (men_ycoord < 50.0)*(men_ycoord-10),
                # if line is higher than vertical middle (50%) go upper, and vice versa
                'Men')
        ax.text(2004,
                (women_ycoord >= 50.0)*(women_ycoord+7) + (women_ycoord < 50.0)*(women_ycoord-10),
                # same logic
                'Women')
        return None

# %%
fig = plt.figure(figsize=(18, 18))

## a loop for STEM_cats
for sp in range(0, 16, 3):
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+1)    
    plot_ax(stem_cats, ax, i)    
    tune_ax(stem_cats, ax)
    
    if sp == 0:
        add_labes(stem_cats, ax, i)
    elif sp == 15:
        add_labes(stem_cats, ax, i)
        
## a loop for lib_arts_cats
for sp in range(0, 15, 3): # looping until 15 to have 5 plots instead of 6
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+2)    
    plot_ax(lib_arts_cats, ax, i)    
    tune_ax(lib_arts_cats, ax)
    
    if sp == 0:
        add_labes(lib_arts_cats, ax, i)
        
## a loop for other_cats
for sp in range(0, 16, 3): 
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+3)    
    plot_ax(other_cats, ax, i)    
    tune_ax(other_cats, ax)
    
    if sp == 0:
        add_labes(other_cats, ax, i)
    elif sp == 15:
        add_labes(other_cats, ax, i)

# %% [markdown]
# ### Removing x labels

# %%
# Reusable functions

def plot_ax(lst, ax, i):
    ax.plot(women_degrees['Year'], women_degrees[lst[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lst[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lst[i])
    return None

def tune_ax(lst, ax): # 'lst' holds categories names 
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)    
    
    ax.tick_params(bottom="off", top="off", 
                   left="off", right="off", labelbottom='off') ## <- change here
    return None

def add_labes(lst, ax, i):
        men_ycoord = 100-women_degrees.loc[41, lst[i]]
        women_ycoord = women_degrees.loc[41, lst[i]]
        ax.text(2005, 
                (men_ycoord >= 50.0)*(men_ycoord+7) + (men_ycoord < 50.0)*(men_ycoord-10),
                # if line is higher than vertical middle (50%) go upper, and vice versa
                'Men')
        ax.text(2004,
                (women_ycoord >= 50.0)*(women_ycoord+7) + (women_ycoord < 50.0)*(women_ycoord-10),
                # same logic
                'Women')
        return None

# %%
fig = plt.figure(figsize=(18, 18))

## a loop for STEM_cats
for sp in range(0, 16, 3):
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+1)    
    plot_ax(stem_cats, ax, i)    
    tune_ax(stem_cats, ax)
    
    if sp == 0:
        add_labes(stem_cats, ax, i)
    elif sp == 15:
        add_labes(stem_cats, ax, i)
        ax.tick_params(labelbottom='on') # <- change here
        
## a loop for lib_arts_cats
for sp in range(0, 15, 3): # looping until 15 to have 5 plots instead of 6
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+2)    
    plot_ax(lib_arts_cats, ax, i)    
    tune_ax(lib_arts_cats, ax)
    
    if sp == 0:
        add_labes(lib_arts_cats, ax, i)
    elif sp == 12:
        ax.tick_params(labelbottom='on') # <- change here
        
## a loop for other_cats
for sp in range(0, 16, 3): 
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+3)    
    plot_ax(other_cats, ax, i)    
    tune_ax(other_cats, ax)
    
    if sp == 0:
        add_labes(other_cats, ax, i)
    elif sp == 15:
        add_labes(other_cats, ax, i)
        ax.tick_params(labelbottom='on') # <- change here

# %% [markdown]
# ### changing y ticks and adding horizontal line and exporting the plot to file

# %%
# Reusable functions

def plot_ax(lst, ax, i):
    ax.plot(women_degrees['Year'], women_degrees[lst[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lst[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lst[i])
    return None

def tune_ax(lst, ax): # 'lst' holds categories names 
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)    
    
    ax.tick_params(bottom="off", top="off", 
                   left="off", right="off", labelbottom='off') 
    ax.set_yticks([0,100])  # <- change here
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <- change here
    return None

def add_labes(lst, ax, i):
        men_ycoord = 100-women_degrees.loc[41, lst[i]]
        women_ycoord = women_degrees.loc[41, lst[i]]
        ax.text(2005, 
                (men_ycoord >= 50.0)*(men_ycoord+7) + (men_ycoord < 50.0)*(men_ycoord-10),
                # if line is higher than vertical middle (50%) go upper, and vice versa
                'Men')
        ax.text(2004,
                (women_ycoord >= 50.0)*(women_ycoord+7) + (women_ycoord < 50.0)*(women_ycoord-10),
                # same logic
                'Women')
        return None

# %%
fig = plt.figure(figsize=(18, 18))

## a loop for STEM_cats
for sp in range(0, 16, 3):
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+1)    
    plot_ax(stem_cats, ax, i)    
    tune_ax(stem_cats, ax)
    
    if sp == 0:
        add_labes(stem_cats, ax, i)
    elif sp == 15:
        add_labes(stem_cats, ax, i)
        ax.tick_params(labelbottom='on') 
        
## a loop for lib_arts_cats
for sp in range(0, 15, 3): # looping until 15 to have 5 plots instead of 6
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+2)    
    plot_ax(lib_arts_cats, ax, i)    
    tune_ax(lib_arts_cats, ax)
    
    if sp == 0:
        add_labes(lib_arts_cats, ax, i)
    elif sp == 12:
        ax.tick_params(labelbottom='on') 
        
## a loop for other_cats
for sp in range(0, 16, 3): 
    i = int(sp/3) # index in 'cats' list
    ax = fig.add_subplot(6, 3, sp+3)    
    plot_ax(other_cats, ax, i)    
    tune_ax(other_cats, ax)
    
    if sp == 0:
        add_labes(other_cats, ax, i)
    elif sp == 15:
        add_labes(other_cats, ax, i)
        ax.tick_params(labelbottom='on') 
        
plt.savefig('gender_degrees.png')
plt.show()

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'
